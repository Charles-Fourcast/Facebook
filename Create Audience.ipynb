# %%
# !pip install facebookads
# Out:
# ...
#     100% |████████████████████████████████| 296kB 2.0MB/s ta 0:00:011
# ...
#   Running setup.py bdist_wheel for facebookads ... done
#   Stored in directory: /home/charly/.cache/pip/wheels/24/e0/69/366de5a95e7181d965482c14bee0641b2d5630e4f7ffb1700b
# Successfully built facebookads
# ...

# %%
from facebookads.adobjects.customaudience import CustomAudience
from facebookads.adobjects.adaccount import AdAccount

# %%
from facebookads.api import FacebookAdsApi
from facebookads import adobjects

my_app_id = '1733429803385465'
my_app_secret = 'aa66dcbdf97e726c07c3e7e4e59d3ab1'
my_access_token = 'EAAYoi5OsgnkBAD7j2B1FPDe5zQZCzSKtbFEQEkYUNfHNqzAZBU23vkswVm4rPgF9Six9UDfhBcYsQEbSkb1pb7XnEJAIynilJiJJyHtXzZCps4bHhszylV2kCLAuGQfYABLHUbVI8V81qGa25ZBEYTZAUlrXYf4YCBKXLunFZCLB8ENJZBeSPvI4ZAHWZCkF0bDQZD'
FacebookAdsApi.init(my_app_id, my_app_secret, my_access_token)

# %%
ad_account = AdAccount(fbid='act_64916754')

params = {
    CustomAudience.Field.subtype: CustomAudience.Subtype.custom,
    CustomAudience.Field.name: 'My new CA',
    CustomAudience.Field.description: 'People who bought on my website',
}
audience = ad_account.create_custom_audience(params=params)
# Out:
# ---------------------------------------------------------------------------
# FacebookRequestError                      Traceback (most recent call last)
# <ipython-input-47-3ff6b9ce8d8b> in <module>()
#       6     CustomAudience.Field.description: 'People who bought on my website',
#       7 }
# ----> 8 audience = ad_account.create_custom_audience(params=params)
#
# ~/anaconda3/lib/python3.6/site-packages/facebookads/adobjects/adaccount.py in create_custom_audience(self, fields, params, batch, pending)
#    1443         else:
#    1444             self.assure_call()
# -> 1445             return request.execute()
#    1446
#    1447     def get_custom_audiences_tos(self, fields=None, params=None, batch=None, pending=False):
#
# ~/anaconda3/lib/python3.6/site-packages/facebookads/api.py in execute(self)
#     672                 params=params,
#     673                 files=files,
# --> 674                 api_version=self._api_version,
#     675             )
# ...

# %%
import numpy as np
import pandas as pd

# %%
df_cust_data = pd.read_excel('../mazda/mazda.xlsx','Customer data')

# %%
df_cust_data[]
# Out:
#      Contact Row ID Preferred Language Personal Title_I           First Name  \
# 0         1-2D4NCGV                FRA               Mr                Alain
# 1          1-2MBQY1                FRA               Mr              Jacques
# 2         1-PQM15SY                NLD               Mr              Patrick
# 3         1-8675UCA                FRA           Family      Van Ceulebroeck
# 4         1-PBPAB7Q                NLD               Mr                  LUC
# 5         1-PE3ST4T                FRA               Mr                 JEAN
# 6         1-PF4PXYB                FRA               Mr              Vassily
# 7         1-PGJMJKD                NLD           Family                Chris
# 8         1-3JYFFUW                NLD               Mr                Lukas
# 9          1-4UVT27                FRA               Mr             PHILIPPE
# 10        1-PMJ9V5F                FRA               Mr                 Eric
# ...
